# %%
from random import randint


answer = randint(1,100)
print(answer)

while True:
    if answer == guess:
        print("That's correct!")
        break
    elif answer > guess:
        print("Up!")
    elif answer < guess:
        print("Down!")
# Out:
# 69
# Guess the num(1-100) : 1
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# Up!
# ...
